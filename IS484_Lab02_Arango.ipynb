# %% [markdown]
# ## Laboratorio 002

# %% [markdown]
# ### Representación de un problema mediante estados
# **Parte A:** Completar la cha del problema para el siguiente caso: un repartidor debe ir desde el Almacén hasta la Zona Norte, pudiendo pasar por distintos puntos intermedios de la ciudad.

# %% [markdown]
# **Estado** | **Descripcion**
# --- | ---
# *Estado inicial:* | El repartidor se encuentra en el **Almacen**
# *Estado objetivo:* | El repartidor ha llegado a la **Zona Norte**
# *Acciones posibles:* | El repartidor se puede desplazar en cualquier punto que este conectado a el
# *Costo de cada accion:* | El costo de cada accion por tramos va ha ser el mismo

# %% [markdown]
# **Parte B:** Representar el mapa de la ciudad como un grafo en Python, usando un diccionario de listas (cada clave es un punto, cada valor es la lista de puntos conectados directamente):

# %%
mapa = {
    "almacen":  ["centro", "terminal"],
    "centro": ["almacen", "mercado", "zonaNorte"],
    "terminal": ["almacen", "mercado"],
    "mercado": ["centro", "terminal", "zonaNorte"],
    "zonaNorte": ["centro", "mercado"]
}
print(mapa)
# Out:
# {'almacen': ['centro', 'terminal'], 'centro': ['almacen', 'mercado', 'zonaNorte'], 'terminal': ['almacen', 'mercado'], 'mercado': ['centro', 'terminal', 'zonaNorte'], 'zonaNorte': ['centro', 'mercado']}

# %% [markdown]
# ### Implementación de BFS
# Completar la función de búsqueda en amplitud, usando una cola (lista de Python, con .pop(0) para sacar el primer elemento):

# %%
def bfs(grafo, inicio, objetivo):
    """
    Busca el camino mas corto entre 'inicio' y 'objetivo' usando BFS.
    """
    cola = [[inicio]] # cola de caminos, empieza con el estado inicial
    visitados = set()
    
    while cola:
        camino = cola.pop(0) # sacar el primer camino de la cola (FIFO)
        nodo_actual = camino[-1]
        
        if nodo_actual == objetivo:
            return camino
            
        if nodo_actual not in visitados:
            visitados.add(nodo_actual)
            for vecino in grafo[nodo_actual]:
                # Se crea un nuevo camino agregando el vecino y se añade a la cola
                nuevo_camino = camino + [vecino]
                cola.append(nuevo_camino)
                
    return None # no se encontro un camino

resultado = bfs(mapa, "almacen", "zonaNorte")
print("Camino encontrado:", resultado)
# Out:
# Camino encontrado: ['almacen', 'centro', 'zonaNorte']

# %% [markdown]
# **_Interpretacion:_** ¿Que es lo que hace el codigo?
#
# * La `cola = [[inicio]]` se encarga de empezar por un solo camino que contiene solo el nodo de inicio.
# * El bucle `while` repite, busca mientras hayan caminos por explorar.
# * Con `cola.pop(o)` saca el primer camino de la cola.
# * El primer `if` si se llega al objetivo, devuelve el camino completo.
# * El segundo `if` marca como visitado al nodo si este no se ha expandido.
# * El bucle `for` crea un nuevo caminoo agregando al vecino y lo añade a la cola.
# * Finalmente `return none` en el caso de que no encuentre un camino.
