# %% [markdown]
# ## *Semana 3: Fundamentos Estadísticos y Optimización*

# %% [markdown]
# **4.2** **Explorando el problema: ¿qué influye en la matrícula de cada semestre?**
#
# **Parte A:** Guardar *matricula_sistemas.csv* en la misma carpeta que el notebook y cargarlo
#
# * num_postulantes: cuántos alumnos postularon a la escuela ese semestre.
# * becas_otorgadas: cuántas becas se otorgaron ese semestre.
# * tasa_desercion_anterior: qué fracción de alumnos abandonó el semestre previo.
# * campania_difusion: si hubo (1) o no (0) una campaña de difusión de la escuela.
# * num_matriculados (variable objetivo): cuántos alumnos se matricularon nalmente: esto es lo que se quiere predecir

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
matricula = pd.read_csv("matricula_sistemas.csv")
matricula.describe()
# Out:
#        num_postulantes  becas_otorgadas  tasa_desercion_anterior  \
# count        24.000000        24.000000                24.000000
# mean        231.125000        18.250000                 0.129917
# std          41.277757         6.917212                 0.021055
# min         146.000000         8.000000                 0.096000
# 25%         200.250000        12.750000                 0.110750
# 50%         222.500000        17.500000                 0.127500
# 75%         261.250000        24.250000                 0.150250
# max         311.000000        30.000000                 0.167000
#
#        campania_difusion  num_matriculados
# count          24.000000         24.000000
# mean            0.500000        137.083333
# std             0.510754         34.122435
# min             0.000000         75.000000
# 25%             0.000000        111.500000
# 50%             0.500000        137.000000
# 75%             1.000000        161.500000
# ...

# %% [markdown]
# **Parte B:** Antes de pensar en modelos, conviene entender el comportamiento básico de la matrícula:
# ¿cuántos alumnos se matriculan en promedio? qué tan dispersa es esa cifra de un semestre a otro?
# Calcular los estadísticos descriptivos de num_matriculados:

# %%
col = matricula["num_matriculados"]
print("Media:", col.mean())
print("Mediana:", col.median())
print("Moda:", col.mode().tolist())
print("Rango:", col.max() - col.min())
print("Varianza:", col.var())
print("Desviacion estandar:", col.std())
# Out:
# Media: 137.08333333333334
# Mediana: 137.0
# Moda: [120, 137, 160]
# Rango: 123
# Varianza: 1164.340579710145
# Desviacion estandar: 34.12243513745971
