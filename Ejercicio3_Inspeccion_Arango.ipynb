# %% [markdown]
# ## Ejercicio 3: Inspección visual de un producto
# Problema: en una línea de producción, una cámara captura una pequeña imagen de 5×5 píxeles
# de cada producto, representada como una matriz de NumPy donde cada valor es 0 (píxel normal)
# o 1 (píxel defectuoso). El agente debe decidir qué hacer con el producto según cuántos píxeles
# defectuosos detecta.
# ### Ficha PEAS
#
# | Elemento | Descripción |
# |---|---|
# | **Percepción (S)** | Matriz 5×5 con valores 0 (normal) o 1 (defectuoso) por píxel |
# | **Acciones (A)** | Aprobar, enviar a revisión manual, rechazar |
# | **Entorno (E)** | Línea de producción con productos de distinta calidad pasando frente a la cámara |
# | **Objetivo** | Filtrar productos defectuosos antes de que lleguen al cliente, sin descartar productos buenos |
# | **Medida de desempeño (P)** | Productos defectuosos no detectados (fuga), productos buenos rechazados de más, tiempo de inspección |

# %% [markdown]
# ### Justificación de las reglas de decisión
# Si no tiene defectos, el producto se aprueba directamente. Si tiene entre 1 y 3 defectos, pasa a una revisión manual para determinar si son fallas menores. Si tiene más de 3 defectos, se rechaza directamente porque presenta demasiadas fallas.
#
# | Cantidad de defectos | Acción |
# |---|---|
# | 0 | Aprobar |
# | 1 a 3 | Revisión manual |
# | Más de 3 | Rechazar |

# %% [markdown]
# ### Código

# %%
import numpy as np

def agente_inspeccion(imagen):
    """
    Percepcion (S): matriz 5x5 de NumPy (0 = normal, 1 = defectuoso)
    """
    defectos = np.sum(imagen == 1)  # cuenta cuantas celdas tienen valor 1

    if defectos == 0:
        return "aprobar", "no se detectaron pixeles defectuosos"
    elif defectos <= 3:
        return "revision manual", f"se detectaron {defectos} pixeles defectuosos"
    else:
        return "rechazar", f"se detectaron {defectos} pixeles defectuosos"
